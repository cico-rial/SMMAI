# %% [markdown]
# # Homework 3
# ### Optimization via Gradient Descent.
# Here goes the text of the problem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Backtracking and GD definition
# `Note:` the backtracking and GD function have been modified by Leonardo Chiarioni™ introducing a new parameter: **multivariate**

# %%
def backtracking(f, grad_f, x, multivariate):
    """
    This function is a simple implementation of the backtracking algorithm for
    the GD (Gradient Descent) method.
    
    f: function. The function that we want to optimize.
    grad_f: function. The gradient of f(x).
    x: ndarray. The actual iterate x_k.
    multivariate: boolean. Indicate whether the function f 
    is multivariate or not.
    """

    if multivariate:
        norm = np.linalg.norm
    else:
        norm = np.abs
        
    alpha = 1
    c = 0.8
    tau = 0.25
    
    while f(x - alpha * grad_f(x)) > f(x) - c * alpha * norm(grad_f(x)) ** 2:
        alpha = tau * alpha
        
        if alpha < 1e-3:
            break
    return alpha



def GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=False, alpha=1, multivariate=True):
    """
    This function implements the Gradient Descent algorithm.
    """
    if multivariate:
        norm = np.linalg.norm
    else:
        norm = np.abs
    
    # Initialize x_k
    x_k = x0
    
    # counter
    k = 0
    
    # Initialize the outputs
    x = [x0]
    f_val = [f(x0)]
    grads = [grad_f(x0)]
    err = [norm(grad_f(x0))]
    
    # Loop
    condition = True
    while condition:
        # Update alpha
        if back_tracking:
            alpha = backtracking(f, grad_f, x_k, multivariate)
        # Update x
        x_k = x_k - alpha*grad_f(x_k)
        
        # Update outputs
        x.append(x_k)
        f_val.append(f(x_k))
        grads.append(grad_f(x_k))
        err.append(norm(grad_f(x_k)))
        
        # check criteria
        condition1 = norm(grad_f(x_k)) > (tolf * norm(grad_f(x0)))
        condition2 = norm(x_k) > tolx
        condition3 = k < kmax
        condition = condition1 and condition2 and condition3
        
        # update k
        k += 1
            
    return x_k, k, np.array(x), np.array(f_val), np.array(grads), np.array(err)

def plot_error(k, err):
    """
    This function enables you to simply plot the error 
    of the gradient descent with respect to the iteration k
    """
    
    plt.figure(figsize=(8,4))
    plt.plot(np.arange(1,k+2,1), err, 'r-')
    plt.xlabel('k-th iteration')
    plt.ylabel('Error (||\u2207ƒ||_2)')
    plt.title('Error for different k')
    plt.grid()
    plt.show()

# %% [markdown]
# ### Function 1:
# With a step-size of 0.5 you can find the optimal solution in just 1 iteration. Here backtracking guarantees the convergence but with more iterations

# %%
def f(x):
    x1 = x[0]
    x2 = x[1]
    return (x1 - 3)**2 + (x2 - 1)**2

def grad_f(x):
    x1 = x[0]
    x2 = x[1]
    return np.array([2*(x1 - 3), 2*(x2 - 1)])

# Test (for example)
x0 = np.array([0,0])
kmax = 1_00
tolf = tolx = 1e-5

x_sol, k, x, f_val, grads, err = GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=True, alpha=1)
print(f'x = {x_sol}')
print(f"k: {k}")
print(f'error: {err[k]}')

plot_error(k, err)
# Out:
# x = [2.99997297 0.99999099]
# k: 87
# error: 5.698107109779695e-05

# %% [markdown]
# # Function 2:
# Here backtracking is almost essential to avoid divergence (overflow in this case) unless you choose a very small step size.
# Backtracking allows you to find the solution with a few iterations

# %%
def f(x):
    x1 = x[0]
    x2 = x[1]
    return 10*(x1 - 1)**2 + (x2 - 2)**2

def grad_f(x):
    x1 = x[0]
    x2 = x[1]
    return np.array([20*(x1-1), 2*(x2 - 2)])

# Test (for example)
x0 = np.array([0,0])
kmax = 1_00
tolf = tolx = 1e-5

x_sol, k, x, f_val, grads, err = GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=True, alpha=1)
print(f'x = {x_sol}')
print(f"k: {k}")
print(f'error: {err[k]}')

plot_error(k, err)
# Out:
# x = [1.         1.99990644]
# k: 80
# error: 0.00018712416290789236

# %% [markdown]
# ### Function 3:
# Backtracking doesn't allow convergence here (high error at the end). A step-size greater than about 0.22 leads to divergence

# %%
def f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return 0.5*np.linalg.norm(A@x_true-b)**2

def grad_f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return A.T@(A@x-b)

# Test (for example)
x0 = np.zeros(5)
kmax = 1_00
tolf = tolx = 1e-5

x_sol, k, x, f_val, grads, err = GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=False, alpha=0.22, multivariate=True)
print(f'x = {x_sol}')
print(f"k: {k}")
print(f'error: {err[k]}')

plot_error(k, err)
# Out:
# x = [1.02819831 1.02445669 1.02435089 1.01341295 1.00123852]
# k: 101
# error: 0.39175266323203983

# %% [markdown]
# ### Function 4:
# Backtracking doesn't allow convergence here (high error at the end). A step-size greater than about 0.2 leads to divergence

# %%
l = 0.5
def f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return 0.5*np.linalg.norm(A@x_true-b)**2 + 0.5*l*np.linalg.norm(x)**2

def grad_f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return A.T@(A@x-b) + l*x

# Test (for example)
x0 = np.zeros(5)
kmax = 1_00
tolf = tolx = 1e-5

x_sol, k, x, f_val, grads, err = GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=False, alpha=0.2, multivariate=True)
print(f'x = {x_sol}')
print(f"k: {k}")
print(f'error: {err[k]}')

plot_error(k, err)
# Out:
# x = [1.02331498 0.9828142  0.91717621 0.86991013 0.83596606]
# k: 94
# error: 0.0001741027221596313

# %% [markdown]
# ### Function 5:
# Backtracking is useful to avoid non optimal solution or even divergence, unless a very tiny step-size is used. If the starting point is towards the negative side, the other (local) minimum will be found.

# %%
def f(x):
    return x**4 + x**3 -2*x**2 -2*x

def grad_f(x):
    return 4*x**3 + 3*x**2 + -4*x -2

# Test (for example)
x0 = 0
kmax = 1_00
tolf = tolx = 1e-5

x_sol, k, x, f_val, grads, err = GD(f, grad_f, x0, kmax, tolf, tolx, back_tracking=True, alpha=1, multivariate=False)
print(f'x = {x_sol}')
print(f"k: {k}")
print(f'error: {err[k]}')

plot_error(k, err)
# Out:
# x = 0.922223172080442
# k: 63
# error: 1.9027681881222946e-05

# %%
a,b = -2, 2
x_val = np.linspace(a,b,200)
plt.figure(figsize=(10,4))
plt.scatter(x, f(x), c='black', marker='x', s=20, label='minimum')
plt.plot(x_val, f(x_val), 'r-', label='f(x)')
plt.grid()
plt.legend()
plt.show()
