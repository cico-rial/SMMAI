# %% [markdown]
# # Homework 3
# ### Optimization via Gradient Descent.
# Here goes the text of the problem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Backtracking and GD definition
# `Note:` the backtracking and GD function have been modified by Leonardo Chiarioni™ introducing a new parameter: **multivariate**

# %%
def backtracking(f, grad_f, x, multivariate):
    """
    This function is a simple implementation of the backtracking algorithm for
    the GD (Gradient Descent) method.
    
    f: function. The function that we want to optimize.
    grad_f: function. The gradient of f(x).
    x: ndarray. The actual iterate x_k.
    multivariate: boolean. Indicate whether the function f 
    is multivariate or not.
    """

    if multivariate:
        norm = np.linalg.norm
    else:
        norm = np.abs
        
    alpha = 1
    c = 0.8
    tau = 0.25
    
    while f(x - alpha * grad_f(x)) > f(x) - c * alpha * norm(grad_f(x)) ** 2:
        alpha = tau * alpha
        
        if alpha < 1e-3:
            break
    return alpha



def GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=False, alpha=1, multivariate=True, plot=False):
    """
    This function implements the Gradient Descent algorithm.
    """
    if multivariate:
        norm = np.linalg.norm
    else:
        norm = np.abs
    
    # Initialize x_k
    x_k = x0
    
    # counter
    k = 0
    
    # Initialize the outputs
    x = [x0]
    f_val = [f(x0)]
    grads = [grad_f(x0)]
    err_grad = [norm(grad_f(x0))]
    err_sol = [norm(x_true - x0)]
    
    if plot:
        x_range = np.linspace(-10, 10, 400)
        y_range = np.linspace(-10, 10, 400)
        X, Y = np.meshgrid(x_range, y_range)
        Z = f((X, Y))

        plt.figure(figsize=(5, 5))
        plt.contour(X, Y, Z, levels=np.logspace(-2, 3, 20), cmap='viridis')
        plt.scatter(x0[0], x0[1], color='red', marker='o', label='Initial Point')
    
    # Loop
    condition = True
    while condition:
        # Update alpha
        if back_tracking:
            alpha = backtracking(f, grad_f, x_k, multivariate)
        # Update x
        x_k = x_k - alpha*grad_f(x_k)
        
        # Update outputs
        x.append(x_k)
        f_val.append(f(x_k))
        grads.append(grad_f(x_k))
        err_grad.append(norm(grad_f(x_k)))
        err_sol.append(norm(x_true - x_k))
        
        if plot:
            plt.scatter(x_k[0], x_k[1], color='blue', marker='o', label=f'Iteration {k}')
               
        # check criteria
        condition1 = norm(grad_f(x_k)) > (tolf * norm(grad_f(x0)))
        condition2 = norm(x_k) > tolx
        condition3 = k < kmax
        condition = condition1 and condition2 and condition3
       
        # update k
        k += 1
        
    if plot:
        plt.title('Gradient Descent Iterations')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.show()

    return x_k, k, np.array(x), np.array(f_val), np.array(grads), np.array(err_grad), np.array(err_sol)

def plot_errors(x, k, err_grad, err_sol, text, figsize=(10,3)):
    """
    This function enables you to simply plot the error 
    of the gradient descent with respect to the iteration k
    """
    print(text)
    print(f'x = {x[-1]}')
    print(f"k: {k}")
    print(f'gradient error: {err_grad[k]}')
    print(f'solution error: {err_sol[k]}')
    
    plt.figure(figsize=figsize)
    plt.subplot(1,2,1)
    plt.plot(np.arange(1,k+2,1), err_grad, 'r-')
    plt.xlabel('k-th iteration')
    plt.title('Gradient error')
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.plot(np.arange(1,k+2,1), err_sol, 'r-')
    plt.xlabel('k-th iteration')
    plt.title('Solution Error')
    plt.grid()
    
    plt.show()

# %% [markdown]
# ### Function 1:
# ![image-2.png](attachment:image-2.png)

# %%
def f(x):
    x1 = x[0]
    x2 = x[1]
    return (x1 - 3)**2 + (x2 - 1)**2

def grad_f(x):
    x1 = x[0]
    x2 = x[1]
    return np.array([2*(x1 - 3), 2*(x2 - 1)])

# %% [markdown]
# Backtracking = **True**, convergence in 87 iterations

# %%
x0 = np.array([0,0])
kmax = 1_00
tolf = tolx = 1e-5
x_true = np.array([3,1])

x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, plot=True)
plot_errors(x, k, err_grad, err_sol, "back_tracking = True")
# Out:
# back_tracking = True
# x = [2.99997297 0.99999099]
# k: 87
# gradient error: 5.698107109779695e-05
# solution error: 2.8490535548898475e-05

# %% [markdown]
# Backtracking = **False**, high learning rate: **Divergence!**

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=1.1)
plot_errors(x, k, err_grad, err_sol, 'alpha = 1.1')
# Out:
# alpha = 1.1
# x = [2.98144711e+08 9.93815704e+07]
# k: 101
# gradient error: 628544233.6592741
# solution error: 314272116.82963705

# %% [markdown]
# Backtracking = False, correct learning rate: just **1 iteration!**

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.5)
plot_errors(x, k, err_grad, err_sol, 'alpha = 0.5')
# Out:
# alpha = 0.5
# x = [3. 1.]
# k: 1
# gradient error: 0.0
# solution error: 0.0

# %% [markdown]
# # Function 2:
# ![image-2.png](attachment:image-2.png)

# %%
def f(x):
    x1 = x[0]
    x2 = x[1]
    return 10*(x1 - 1)**2 + (x2 - 2)**2

def grad_f(x):
    x1 = x[0]
    x2 = x[1]
    return np.array([20*(x1-1), 2*(x2 - 2)])

# %% [markdown]
# Without Backtracking, convergence is very slow (or even divergence is reached if not an appropriate step size is chosen). This is probably because the contribution of x1 on the gradient is way higher than the contribution of x2, so a lot of bounces back and forth are present on seeking for the minima.

# %%
x0 = np.array([0,0])
kmax = 1_00
tolf = tolx = 1e-5
x_true = np.array([1,2])

x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.5)
plot_errors(x, k, err_grad, err_sol, 'alpha = 0.5')
# Out:
# alpha = 0.5
# x = [2.3905259e+96 2.0000000e+00]
# k: 101
# gradient error: 4.7810517997657446e+97
# solution error: 2.390525899882872e+96

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.1, plot=True)
plot_errors(x, k, err_grad, err_sol, 'alpha = 0.1')
# Out:
# alpha = 0.1
# x = [2. 2.]
# k: 101
# gradient error: 20.0
# solution error: 1.0

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, plot=True)
plot_errors(x, k, err_grad, err_sol, 'back_tracking = True')
# Out:
# back_tracking = True
# x = [1.         1.99990644]
# k: 80
# gradient error: 0.00018712416290789236
# solution error: 9.356208145394618e-05

# %% [markdown]
# ### Function 3:
# ![image-3.png](attachment:image-3.png)
# Backtracking is superslow with this function. Experimentally, a step-size greater than about 0.22 leads to divergence. A step size of 0.2 enables us to reach an optimal solution in 200 iterations.

# %%
def f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return 0.5*np.linalg.norm(A@x_true-b)**2

def grad_f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return A.T@(A@x-b)

# %%
n = 5
x0 = np.zeros(n)
kmax = 1_000
tolf = tolx = 1e-5
x_true = np.ones((n,))


x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, multivariate=True)
plot_errors(x, k, err_grad, err_sol, "n = 5\nback_tracking = True")
# Out:
# n = 5
# back_tracking = True
# x = [1.08809647 1.04216717 0.96484371 0.91038928 0.87177323]
# k: 1001
# gradient error: 0.24078424241395305
# solution error: 0.18774240474489157

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.2, multivariate=True)
plot_errors(x_sol, k, err_grad, err_sol, f"n = {n}\nalpha = 0.2")
# Out:
# n = 5
# alpha = 0.2
# x = 0.9937207295808961
# k: 202
# gradient error: 0.0001892211822669669
# solution error: 0.009665313595958042

# %%
n = 10
x0 = np.zeros(n)
kmax = 1_000
tolf = tolx = 1e-5
x_true = np.ones((n,))


x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, multivariate=True)
plot_errors(x, k, err_grad, err_sol, f'n = {n}\nback_tracking = True')
# Out:
# n = 10
# back_tracking = True
# x = [0.95804474 1.07792544 1.07330853 1.04863969 1.02062141 0.99387924
#  0.96970003 0.94829485 0.92951041 0.91308113]
# k: 1001
# gradient error: 0.10608199996503073
# solution error: 0.17930551405861303

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.1, multivariate=True)
plot_errors(x_sol, k, err_grad, err_sol, f'n = {n}\nalpha = 0.2')
# Out:
# n = 10
# alpha = 0.2
# x = 3758916257973374.5
# k: 1001
# gradient error: 4.08800383571633e+17
# solution error: 2.0067704686723864e+16

# %% [markdown]
# ### Function 4:
# ![image.png](attachment:image.png)
# Backtracking doesn't allow convergence here (high error at the end). A step-size greater than about 0.2 leads to divergence

# %%
l = 0.5
def f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return 0.5*np.linalg.norm(A@x_true-b)**2 + 0.5*l*np.linalg.norm(x)**2

def grad_f(x):
    n = x.shape[0]
    v = np.linspace(0,1,n)
    x_true = np.ones((n,))
    A = np.vander(v, increasing=True)
    b = A @ x_true
    return A.T@(A@x-b) + l*x

# %%
n = 5
x0 = np.zeros(n)
kmax = 1_00
tolf = tolx = 1e-5
x_true = np.ones((n,))

x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, multivariate=True)
plot_errors(x, k, err_grad, err_sol, f'l = {l}\nn = {n}\nback_tracking = True')
# Out:
# l = 0.5
# n = 5
# back_tracking = True
# x = [0.7749984  0.55853428 0.47863039 0.43304049 0.40425765]
# k: 101
# gradient error: 7.486627069426956
# solution error: 1.0925639602544117

# %%
x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, alpha=0.2, multivariate=True)
plot_errors(x, k, err_grad, err_sol, f'l = {l}\nn = {n}\nalpha = 0.2')
# Out:
# l = 0.5
# n = 5
# alpha = 0.2
# x = [1.02331498 0.9828142  0.91717621 0.86991013 0.83596606]
# k: 94
# gradient error: 0.0001741027221596313
# solution error: 0.2270005061353439

# %% [markdown]
# ### Function 5:
# ![image.png](attachment:image.png)
# Backtracking is useful to avoid non optimal solution or even divergence, unless a very tiny step-size is used. If the starting point is towards the negative side, the other (local) minimum will be found.

# %%
def f(x):
    return x**4 + x**3 -2*x**2 -2*x

def grad_f(x):
    return 4*x**3 + 3*x**2 + -4*x -2

# %%
x0 = 0
kmax = 1_00
tolf = tolx = 1e-5
x_true = 0.9222247929324 # computed using geogebra

x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, multivariate=False)
plot_errors(x, k, err_grad, err_sol, 'back_tracking=True')

a,b = -2, 2
x_val = np.linspace(a,b,200)
plt.figure(figsize=(10,4))
plt.scatter(x, f(x), c='black', marker='x', s=20, label='minimum')
plt.plot(x_val, f(x_val), 'r-', label='f(x)')
plt.grid()
plt.legend()
plt.show()
# Out:
# back_tracking=True
# x = 0.922223172080442
# k: 63
# gradient error: 1.9027681881222946e-05
# solution error: 1.6208519579841152e-06

# %%
x0 = -0.5

x_sol, k, x, f_val, grads, err_grad, err_sol = GD(f, grad_f, x0, kmax, tolf, tolx, x_true, back_tracking=True, multivariate=False)
plot_errors(x, k, err_grad, err_sol, 'back_tracking=True')

a,b = -2, 2
x_val = np.linspace(a,b,200)
plt.figure(figsize=(10,4))
plt.scatter(x, f(x), c='black', marker='x', s=20, label='minimum')
plt.plot(x_val, f(x_val), 'r-', label='f(x)')
plt.grid()
plt.legend()
plt.show()
# Out:
# back_tracking=True
# x = -1.232239115439945
# k: 101
# gradient error: 3.4354306714945437e-06
# solution error: 2.154463908372345
